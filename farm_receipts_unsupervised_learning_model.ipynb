# %% [markdown]
# # Unsupervised learning exercise
#
# This module is an exercise in unsupervised learning tools in sklearn.  The exercise is going to take county-level dairy sales data from the 2022 NASS Census dataset to group and label distinct dairy county labels.

# %%
# modules
import os
import pandas as pd
import numpy as np
from sqlalchemy import create_engine
import psycopg2
import matplotlib.pyplot as plt

import cattle_cycle_pkg.nass as nass
import cattle_cycle_pkg.env_vars as env_vars

# %%
# SQL engine and select statements

# create sql connection
user = env_vars.mktdb_user()
password = env_vars.mktdb_passwd()
server = env_vars.mktdb_server()

connection_string = f'postgresql://{user}:{password}@{server}/mktdb'
eng = create_engine(connection_string)
conn = eng.connect()

# Pull Dairy Data
dairy_sales_qry = """
select *
from nass_cen2022_fmt
where "GROUP_DESC" in ('DAIRY')
    and "AGG_LEVEL_DESC" in ('COUNTY')
    and "STATISTICCAT_DESC" in ('SALES')
    and "UNIT_DESC" in ('$')
    and "DOMAIN_DESC" in ('TOTAL')
    and "DOMAINCAT_DESC" in ('NOT SPECIFIED')
;
"""

dairy_co_df = pd.read_sql(dairy_sales_qry, con=conn)

print(dairy_co_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1770 entries, 0 to 1769
# Data columns (total 34 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   SOURCE_DESC            1770 non-null   object
#  1   SECTOR_DESC            1770 non-null   object
#  2   GROUP_DESC             1770 non-null   object
#  3   COMMODITY_DESC         1770 non-null   object
#  4   CLASS_DESC             1770 non-null   object
#  5   PRODN_PRACTICE_DESC    1770 non-null   object
#  6   UTIL_PRACTICE_DESC     1770 non-null   object
#  7   STATISTICCAT_DESC      1770 non-null   object
#  8   UNIT_DESC              1770 non-null   object
#  9   SHORT_DESC             1770 non-null   object
#  10  DOMAIN_DESC            1770 non-null   object
#  11  DOMAINCAT_DESC         1770 non-null   object
#  12  AGG_LEVEL_DESC         1770 non-null   object
#  13  STATE_ANSI             1770 non-null   object
#  14  STATE_FIPS_CODE        1770 non-null   object
#  15  STATE_FIPS             1770 non-null   object
#  16  STATE_ALPHA            1770 non-null   object
#  17  STATE_NAME             1770 non-null   object
#  18  ASD_CODE               1770 non-null   object
#  19  ASD_DESC               1770 non-null   object
#  20  COUNTY_CODE            1770 non-null   object
#  21  COUNTY_FIPS            1770 non-null   object
#  22  FULL_FIPS              1770 non-null   object
#  23  COUNTY_NAME            1770 non-null   object
#  24  LOCATION_DESC          1770 non-null   object
#  25  YEAR                   1770 non-null   int64
#  26  FREQ_DESC              1770 non-null   object
#  27  BEGIN_CODE             1770 non-null   int64
#  28  END_CODE               1770 non-null   int64
#  29  REFERENCE_PERIOD_DESC  1770 non-null   object
#  30  WEEK_ENDING            0 non-null      object
#  31  LOAD_TIME              1770 non-null   datetime64[ns]
#  32  VALUE                  901 non-null    float64
#  33  CV                     0 non-null      object
# dtypes: datetime64[ns](1), float64(1), int64(3), object(29)
# memory usage: 470.3+ KB
# None

# %%
# display(dairy_co_df.tail())
dairy_co_not_nan = dairy_co_df.dropna(subset=['VALUE'])
dairy_co_not_nan.groupby(['LOCATION_DESC', 'FULL_FIPS', 'STATE_FIPS', 'COUNTY_CODE'])['VALUE'].describe()
# Out:
#                                                                              count  \
# LOCATION_DESC                              FULL_FIPS STATE_FIPS COUNTY_CODE
# ALABAMA, UPPER PLAINS & PIEDMONT, CHAMBERS 1 17.0    1          17.            1.0
# ARIZONA, NORTHERN, GILA                    4 7.0     4          7.0            1.0
# ARIZONA, SOUTHERN, MARICOPA                4 13.0    4          13.            1.0
# ARIZONA, SOUTHERN, PINAL                   4 21.0    4          21.            1.0
# ARKANSAS, CENTRAL, FAULKNER                5 45.0    5          45.            1.0
# ...                                                                            ...
# WISCONSIN, WEST CENTRAL, PIERCE            5593.0    55         93.            1.0
# WISCONSIN, WEST CENTRAL, ST CROIX          55109.0   55         109            1.0
# WISCONSIN, WEST CENTRAL, TREMPEALEAU       55121.0   55         121            1.0
# WYOMING, NORTHWEST, FREMONT                5613.0    56         13.            1.0
# WYOMING, SOUTH CENTRAL, ALBANY             561.0     56         1.0            1.0
#
#                                                                                     mean  \
# LOCATION_DESC                              FULL_FIPS STATE_FIPS COUNTY_CODE
# ALABAMA, UPPER PLAINS & PIEDMONT, CHAMBERS 1 17.0    1          17.             750000.0
# ARIZONA, NORTHERN, GILA                    4 7.0     4          7.0             415000.0
# ARIZONA, SOUTHERN, MARICOPA                4 13.0    4          13.          598803000.0
# ARIZONA, SOUTHERN, PINAL                   4 21.0    4          21.          399708000.0
# ARKANSAS, CENTRAL, FAULKNER                5 45.0    5          45.            1334000.0
# ...                                                                                  ...
# WISCONSIN, WEST CENTRAL, PIERCE            5593.0    55         93.           64488000.0
# WISCONSIN, WEST CENTRAL, ST CROIX          55109.0   55         109           98919000.0
# WISCONSIN, WEST CENTRAL, TREMPEALEAU       55121.0   55         121          115456000.0
# WYOMING, NORTHWEST, FREMONT                5613.0    56         13.            2503000.0
# WYOMING, SOUTH CENTRAL, ALBANY             561.0     56         1.0              25000.0
#
#                                                                              std  \
# LOCATION_DESC                              FULL_FIPS STATE_FIPS COUNTY_CODE
# ALABAMA, UPPER PLAINS & PIEDMONT, CHAMBERS 1 17.0    1          17.          NaN
# ARIZONA, NORTHERN, GILA                    4 7.0     4          7.0          NaN
# ARIZONA, SOUTHERN, MARICOPA                4 13.0    4          13.          NaN
# ARIZONA, SOUTHERN, PINAL                   4 21.0    4          21.          NaN
# ARKANSAS, CENTRAL, FAULKNER                5 45.0    5          45.          NaN
# ...                                                                          ...
# WISCONSIN, WEST CENTRAL, PIERCE            5593.0    55         93.          NaN
# WISCONSIN, WEST CENTRAL, ST CROIX          55109.0   55         109          NaN
# WISCONSIN, WEST CENTRAL, TREMPEALEAU       55121.0   55         121          NaN
# WYOMING, NORTHWEST, FREMONT                5613.0    56         13.          NaN
# WYOMING, SOUTH CENTRAL, ALBANY             561.0     56         1.0          NaN
#
#                                                                                      min  \
# LOCATION_DESC                              FULL_FIPS STATE_FIPS COUNTY_CODE
# ALABAMA, UPPER PLAINS & PIEDMONT, CHAMBERS 1 17.0    1          17.             750000.0
# ARIZONA, NORTHERN, GILA                    4 7.0     4          7.0             415000.0
# ARIZONA, SOUTHERN, MARICOPA                4 13.0    4          13.          598803000.0
# ARIZONA, SOUTHERN, PINAL                   4 21.0    4          21.          399708000.0
# ARKANSAS, CENTRAL, FAULKNER                5 45.0    5          45.            1334000.0
# ...                                                                                  ...
# WISCONSIN, WEST CENTRAL, PIERCE            5593.0    55         93.           64488000.0
# WISCONSIN, WEST CENTRAL, ST CROIX          55109.0   55         109           98919000.0
# WISCONSIN, WEST CENTRAL, TREMPEALEAU       55121.0   55         121          115456000.0
# WYOMING, NORTHWEST, FREMONT                5613.0    56         13.            2503000.0
# WYOMING, SOUTH CENTRAL, ALBANY             561.0     56         1.0              25000.0
#
#                                                                                      25%  \
# LOCATION_DESC                              FULL_FIPS STATE_FIPS COUNTY_CODE
# ALABAMA, UPPER PLAINS & PIEDMONT, CHAMBERS 1 17.0    1          17.             750000.0
# ARIZONA, NORTHERN, GILA                    4 7.0     4          7.0             415000.0
# ARIZONA, SOUTHERN, MARICOPA                4 13.0    4          13.          598803000.0
# ARIZONA, SOUTHERN, PINAL                   4 21.0    4          21.          399708000.0
# ARKANSAS, CENTRAL, FAULKNER                5 45.0    5          45.            1334000.0
# ...                                                                                  ...
# WISCONSIN, WEST CENTRAL, PIERCE            5593.0    55         93.           64488000.0
# WISCONSIN, WEST CENTRAL, ST CROIX          55109.0   55         109           98919000.0
# WISCONSIN, WEST CENTRAL, TREMPEALEAU       55121.0   55         121          115456000.0
# WYOMING, NORTHWEST, FREMONT                5613.0    56         13.            2503000.0
# WYOMING, SOUTH CENTRAL, ALBANY             561.0     56         1.0              25000.0
#
#                                                                                      50%  \
# LOCATION_DESC                              FULL_FIPS STATE_FIPS COUNTY_CODE
# ALABAMA, UPPER PLAINS & PIEDMONT, CHAMBERS 1 17.0    1          17.             750000.0
# ARIZONA, NORTHERN, GILA                    4 7.0     4          7.0             415000.0
# ARIZONA, SOUTHERN, MARICOPA                4 13.0    4          13.          598803000.0
# ARIZONA, SOUTHERN, PINAL                   4 21.0    4          21.          399708000.0
# ARKANSAS, CENTRAL, FAULKNER                5 45.0    5          45.            1334000.0
# ...                                                                                  ...
# WISCONSIN, WEST CENTRAL, PIERCE            5593.0    55         93.           64488000.0
# WISCONSIN, WEST CENTRAL, ST CROIX          55109.0   55         109           98919000.0
# WISCONSIN, WEST CENTRAL, TREMPEALEAU       55121.0   55         121          115456000.0
# WYOMING, NORTHWEST, FREMONT                5613.0    56         13.            2503000.0
# WYOMING, SOUTH CENTRAL, ALBANY             561.0     56         1.0              25000.0
#
#                                                                                      75%  \
# LOCATION_DESC                              FULL_FIPS STATE_FIPS COUNTY_CODE
# ALABAMA, UPPER PLAINS & PIEDMONT, CHAMBERS 1 17.0    1          17.             750000.0
# ARIZONA, NORTHERN, GILA                    4 7.0     4          7.0             415000.0
# ARIZONA, SOUTHERN, MARICOPA                4 13.0    4          13.          598803000.0
# ARIZONA, SOUTHERN, PINAL                   4 21.0    4          21.          399708000.0
# ARKANSAS, CENTRAL, FAULKNER                5 45.0    5          45.            1334000.0
# ...                                                                                  ...
# WISCONSIN, WEST CENTRAL, PIERCE            5593.0    55         93.           64488000.0
# WISCONSIN, WEST CENTRAL, ST CROIX          55109.0   55         109           98919000.0
# WISCONSIN, WEST CENTRAL, TREMPEALEAU       55121.0   55         121          115456000.0
# WYOMING, NORTHWEST, FREMONT                5613.0    56         13.            2503000.0
# WYOMING, SOUTH CENTRAL, ALBANY             561.0     56         1.0              25000.0
#
#                                                                                      max
# LOCATION_DESC                              FULL_FIPS STATE_FIPS COUNTY_CODE
# ALABAMA, UPPER PLAINS & PIEDMONT, CHAMBERS 1 17.0    1          17.             750000.0
# ARIZONA, NORTHERN, GILA                    4 7.0     4          7.0             415000.0
# ARIZONA, SOUTHERN, MARICOPA                4 13.0    4          13.          598803000.0
# ARIZONA, SOUTHERN, PINAL                   4 21.0    4          21.          399708000.0
# ARKANSAS, CENTRAL, FAULKNER                5 45.0    5          45.            1334000.0
# ...                                                                                  ...
# WISCONSIN, WEST CENTRAL, PIERCE            5593.0    55         93.           64488000.0
# WISCONSIN, WEST CENTRAL, ST CROIX          55109.0   55         109           98919000.0
# WISCONSIN, WEST CENTRAL, TREMPEALEAU       55121.0   55         121          115456000.0
# WYOMING, NORTHWEST, FREMONT                5613.0    56         13.            2503000.0
# WYOMING, SOUTH CENTRAL, ALBANY             561.0     56         1.0              25000.0
#
# [901 rows x 8 columns]
